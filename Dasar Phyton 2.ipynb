# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilhammeffendi/PPLGKEV/blob/main/Dasar%20Phyton%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operator
#
# Operator adalah simbol aritmatika pada bahasa pemrograman Python atau bahasa lainnya, untuk melihat seluruh operator yang tersedia pada Python Anda dapat melihat table di bawah ini.
#
# ![operatoraritmatika.jpg](data:image/jpeg;base64,...)
#
# # Operator Aritmatika
#
# Operator yang akan kita bahas adalah penambahan, pengurangan, perkalian, eksponensial, modulus, dan pembagian. Mari kita lihat operasi aritmatika sederhana pada bahasa pemrograman Python.

# %%
#operator +
a=2
b=3
c=a+b
print(c)

# %%
#operator -
a=100
b=45
c=a-b
print(c)

# %%
#operator *
a=8
b=7
c=a*b
print(c)

# %%
#operator /
a=65
b=5
c=a/b
print(c)

# %%
#operator %
a=10
b=100
c=a%b
print(c)

# %%
#operator **
a=10
b=2
c=a**b
print(c)

# %%
#operator //
a=980
b=10
c=a//b
print(c)

# %%
#operator =
a=60
print(a)

# %%
#operator +=
a=60
a+=20
print(a)

# %%
#operator -=
a=60
a-=50
print(a)

# %%
#operator *=
a=20
a*=5
print(a)

# %%
#operator /=
a=500
a/=50
print(a)

# %% [markdown]
# # Operator Pembanding
#
# Contoh operator pembanding adalah sama dengan, lebih besar dari, serta kurang dari.
#
# a = 5
#
# b = 2
#
# a > b # Lebih besar
#
# True
#
# a < b # kurang dari
#
# False
#
# a == b # sama dengan
#
# False
#
# a >= 5 # lebih besar atau sama dengan
#
# True
#
# b <= 1 # lebih kecil atau sama dengan
#
# False

# %%
#operator ==
a=5
b=3
c=a==b
print(c)

# %%
#operator !=
a=500
b=50
c=a!=b
print(c)
# Out:
# True

# %%
#operator >
a=5
b=6
c=a>b
print(c)

# %%
#operator <
a=5
b=6
c=a<b
print(c)

# %%
#operator >=
a=5
b=6
c=a>=b
print(c)

# %%
#operator <=
a=5
b=6
c=a<=b
print(c)

# %% [markdown]
# # Operator Logika
#
# Operator ini "tidak termasuk", "dan", "dan atau"
#
# a = 10
#
# b = 2
#
# a == 2 and b == 10 # dan
#
# False
#
# a == 10 or b == 10 # atau
#
# True
#
# not(a == 10) # tidak
#
# False
#
# not(a == 2)
#
# True

# %%
#operator and
a=5
b=10
c=a<3 and b>8
print(c)

# %%
#operator or
a=5
b=10
c=a<3 or b>8
print(c)

# %%
#operator not
a=5
b=10
c=not(a<b)
print(c)

# %% [markdown]
# # Conditional Statement
#
# Conditional statement digunakan untuk memeriksa suatu kondisi yang ditentukan sebelumnya apakah nilai nya True atau False.

# %%
#kondisi 1
angka = 10
if angka == 10:
  print("angka adalah 10")

# %%
#kondisi 2
anda_robot = False
if anda_robot:
  print ("Ya, saya robot")
else:
  print ("bukan, saya manusia")

# %%
#kondisi 3
angka = 100
if angka == 10:
  print("angka adalah 10 ")
elif angka < 10:
  print("angka adalah kurang dari 10")
else:
  print("angka adalah lebih dari 10")

# %% [markdown]
# # For Loops
#
# Metode lain yang berguna dalam bahasa pemrograman Python adalah iterator. Hal ini sangat membantu jika Anda ingin melakukan sesuatu beberapa kali. Kita dapat menggunakan suatu cara yang disebut loop atau iterator. Ada dua cara untuk menjalankan perintah tersebut, yaitu dengan for atau while loop.

# %%
for i in range(3):
  print("Hai")

# %%
for i in range(1,3):
  print("Hai")

# %%
for i in range(1,10):
  print ("Ilham")
else:
  print("Selesai")

# %%
for i in range(3):
  for j in range(2):
    print("loop in dalam")
  print("loop in luar")

# %% [markdown]
# # While loops
#
# Dalam bahasa pemrograman Python, terdapat metode loop atau iterator yang lain, yaitu while loop. Kita pun dapat memberikan hasil yang sama seperti yang telah kita lakukan pada for loop dengan menggunakan while loop, seperti contoh di bawah ini:

# %%
i = 5
while i < 10:
  print("angka", i)
  i += 1

# %%
i = 0
while i < 3:
  if i == 3:
          break
  print("Angka", i)
  i += 1

# %%
i = 0
while i < 3:
  print("Angka", i)
  i += 1
else:
  print("Angka lebih besar dari 2")

# %%
i = 0
while i < 5:
  i += 1
  if i == 2:
      continue
  print("Angka", i)
